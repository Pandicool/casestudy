# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key= "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"
)

# %%
def get_completion(prompt , model= "deepseek/deepseek-r1:free"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature= 0.7
    )
    return response.choices[0].message.content
    
print(get_completion("what is 1+1?"))
# Out:
# The result of 1 + 1 is **2**.
#
# In standard arithmetic (base 10), adding the numbers 1 and 1 yields 2. This aligns with basic principles of counting, number-line progression, and real-world examples like combining objects. While alternative systems (e.g., binary or modular arithmetic) can produce different results, the question's context implies standard integer addition.
#
# **Answer:**
# 1 + 1 = 2.
